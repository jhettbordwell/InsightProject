# %% [markdown]
# # In this notebook I will:
# * Go through and remove reviews that only have advertisements? (NOT AT THIS TIME)
# * Tokenize, lemmatize, remove stop words, and remove instances of words that only show up once that aren't special (words that indicate a condition, medication, side effect, or caregiver role)
# * Rejoin processed review into a string for BOW analysis

# %%
import pandas as pd
import numpy as np
import glob

# Haven't decided whether I like nltk or spacy better yet
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet#, stopwords
#stops = stopwords.words('english')
import spacy
from spacy.tokenizer import Tokenizer
import en_core_web_lg
nlp = en_core_web_lg.load()

# Magical gensim module
from gensim import corpora
from gensim.models import LsiModel, LdaModel
from gensim.models.coherencemodel import CoherenceModel

# A method to process text in nltk:
# https://pythonhealthcare.org/2018/12/14/101-pre-processing-data-tokenization-stemming-and-removal-of-stop-words/

# same process in spacy
# https://spacy.io/usage/linguistic-features

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://stackoverflow.com/questions/13928155/spell-checker-for-python/48280566
from autocorrect import Speller
spell = Speller(lang='en')

# %%
# Adjusting stop words in spacy to not lose a bunch of negatives for the sentiment analysis
# for word in [u'nor',u'none',u'not',u'alone',u'no',u'never',u'cannot',u'always']:
#     nlp.vocab[word].is_stop = False
# nlp.vocab[u'thing'].is_stop = True
tokenizer = Tokenizer(nlp.vocab)

# %% [markdown]
# # Working on processing text data

# %%
def get_wordnet_pos(treebank_tag):
    # https://stackoverflow.com/questions/15586721/wordnet-lemmatization-and-pos-tagging-in-python
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
#     elif treebank_tag.startswith('NN'):
#         return wordnet.ADJ # Considering ADJ_SET to be same as ADJ
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

def check_PoS(word):
    return get_wordnet_pos(nltk.pos_tag([word])[0][1])

def useful_synonyms(word):
    # Finding PoS of word
    to_pos = check_PoS(word)
    
    # Finding all synonyms in all the parts of speech
    words = []
    syns = wordnet.synsets(word)

    # Chopping down to most common versions of words...this works for side effects more than words like 'cat'
    if len(syns) >= 2:
        synList = syns[:2]
    else:
        synList = syns
    #     if len(syns)%2 and (len(syns) != 1):
#         synList = syns[:len(syns)//2]
#     else:
#         synList = syns[:len(syns)//2+1]

    # Finding all the forms of a word
    for syn in synList:
        for l in syn.lemmas():
            form = l.derivationally_related_forms()
            words.append(l.name())
            for f in form:
                words.append(f.name())
                
    # Getting all the unique words that match the desired part of speech
    words = list(np.unique(words))
    pos = nltk.pos_tag(words)
    return_words = [word.replace('_',' ') for word, word_pos in pos if get_wordnet_pos(word_pos)==to_pos]

    # Getting around weirdness with somehow dropping PoS for original word if matches to_pos (e.g., with weight)
    if get_wordnet_pos(nltk.pos_tag([word])[0][1]) == to_pos and word not in return_words: return_words.append(word)
        
    return return_words

# %%
# Magic tokenizer thing
def spacyTokenizer(s: str)-> list:
    doc = tokenizer(s.lower().strip())
    tokens = []
    for token in doc:
        if not token.is_stop and token.is_alpha and token.lemma_ != '-PRON-':
            tokens.append(token.lemma_)
        
    return tokens

# %%
def parseRevnew(file, return_df=False):
    reviews = pd.read_csv(file, sep='$')['Comment']
    clean_reviews = [spacyTokenizer(rev.replace('/', ' ')) for rev in reviews]
    cleaner_reviews = findTop(clean_reviews, 50)
    cleaner_reviews = [[spell(word.lower()) for word in rev] for rev in cleaner_reviews]
    
    if return_df:
        return cleaner_reviews, reviews
    else:
        return cleaner_reviews#consider, ignore

def parseSEorig(file):
    sideEff = np.genfromtxt(file, delimiter='$', dtype=str)
    clean_SEs = [[spell(word) for word in spacyTokenizer(SE)] for SE in sideEff]
    cleaner_reviews = findTop(clean_SEs, 3)
    
    return clean_SEs
    
def parseSE_FAERs(file, meds):
    sideEff = pd.read_csv(file, sep='$').set_index('Concept ID').dropna(subset=['Percentage observed'])
    sideEff = sideEff.fillna(value='')

    # Looking for the medication name that has the side effects
    meds_obs = sideEff.copy(deep=True)
    meds_obs['Medications observed'] = [obs.split(', ') for obs in meds_obs['Medications observed']]
    
    medList = []
    for obs in meds_obs['Medications observed']: medList += obs
        
    to_check = np.unique(medList)
    
    Found = False
    for med in meds.lower().split(', '):
        if med in to_check: 
            Found = True
            break # Stop when I've found the name

    sideEff = sideEff[[med in obs for obs in meds_obs['Medications observed']]]
    
    sideEff['Joined'] = sideEff['Definition'] + sideEff['Synonyms']
    check_both = lambda combo: sum([c in nlp.vocab for c in combo.split(' ')]) == len(combo.split(' '))
    sideEff['Joined'] = [', '.join([word for word in words.split(', ') if word.find('-') == -1 and check_both(word)]) for words in sideEff['Joined']]
    clean_SEs = [list(set([spell(word) for word in spacyTokenizer(SE)])) for SE in sideEff['Joined']]
    clean_SEs = [[word for word in SE if len(word) > 3] for SE in clean_SEs]
    clean_SEs = findTop(clean_SEs,5)
    
#     ignore = [SE for SE in clean_SEs if len(SE) <= 2]
#     consider = [SE for SE in clean_SEs if len(SE) > 2]
    
#     # Testing effect of just adding in more language to work with
#     new_consider = []
#     for chunk in consider:
#         extended = []
#         for w in chunk:
#             extended += [s for s in useful_synonyms(w) if s.find('_') == -1]
#         new_consider.append(extended)
    
    return clean_SEs#consider, ignore

# %% [markdown]
# # TFIDF section
# https://buhrmann.github.io/tfidf-analysis.html

# %%
# Not super useful to take the mean across columns, instead look at top 10 scoring words in each side effect
def findTop(strList, keeptop=10):
    tfidf_vectr = TfidfVectorizer()
    corpus = [' '.join(SE) for SE in strList]
    tfidf_score = tfidf_vectr.fit_transform(corpus).toarray()
    features = np.array(tfidf_vectr.get_feature_names())
    
    words = []
    for row in tfidf_score:
        inds = row.argsort()[::-1][:keeptop]
        row_words = []
        for ind in inds:
            if row[ind].round(2) != 0:
                row_words.append(features[ind])
                #print(features[ind],' '*(50-len(features[ind])), row[ind].round(2))
        #print('\n')
        if not row_words:
            row_words = list(features[inds][:5])
        words.append(row_words)
    return words

# %% [markdown]
# # LSA/LDA section

# %%
# https://www.datacamp.com/community/tutorials/discovering-hidden-topics-python
def genDictandDocMatrix(cleaned_text):
    dictionary = corpora.Dictionary(cleaned_text)
    matrix = [dictionary.doc2bow(doc) for doc in cleaned_text]
    return dictionary, matrix

def formatLSAresult(topics:list)->list:
    for topic in topics:
        title = "Topic {:g}: \n".format(topic[0])
        term_cluster = [term.strip().split('*')[1][1:-1] for term in topic[1].split('+')]
        term_weight = [term.strip().split('*')[0] for term in topic[1].split('+')]

        print(title, ', '.join(term_cluster),'\n',', '.join(term_weight))
        
def produceLSA(n_topics, cleanText, n_word_report=10):
    dictionary, matrix = genDictandDocMatrix(cleanText)
    lsamodel = LsiModel(matrix, num_topics=n_topics, id2word=dictionary)
    result = lsamodel.print_topics(num_topics=n_topics, num_words=n_word_report)

    return result, lsamodel

def produceLDA(n_topics, cleanText, n_word_report=10):
    dictionary, matrix = genDictandDocMatrix(cleanText)
    ldamodel = LdaModel(matrix, num_topics=n_topics, id2word=dictionary)
    result = ldamodel.print_topics(num_topics=n_topics, num_words=n_word_report)

    return result, ldamodel

#result, model = produceLSA(10, reviews)
#formatLSAresult(result)

# %%
# Testing out idea of randomly joining side effects and pulling out concepts
from random import shuffle

#test = cleanSEs.copy()

# Joining test results randomly
def try_shuffled_LSA(test, numjoin=5):
    joined_test = []
    inds = np.arange(len(test))
    shuffle(inds)

    if inds.size % numjoin:
        extras = inds[-(inds.size % numjoin):]
        evendiv = inds[:-(inds.size % numjoin)]
        inds = evendiv.reshape((-1,numjoin))
    else:
        extras = None
        inds = inds.reshape((-1,numjoin))


    for ind_set in inds:
        new_join = []
        for ind in ind_set: new_join += test[ind]
        joined_test.append(new_join)

    if type(extras) != type(None):
        for i,ind in enumerate(extras):
            joined_test[i] += test[ind]

    result, model = produceLDA(len(test)//5, joined_test, 10)
    formatLSAresult(result)
#     topics = {}
#      for topic in result:
#         title = "Topic {:g}: \n".format(topic[0])
#         term_cluster = [term.strip().split('*')[1][1:-1] for term in topic[1].split('+')]
#         term_weight = [term.strip().split('*')[0] for term in topic[1].split('+')]
        
#         topics[topic[0]] = term_cluster
        
#     return topics
    
    
def process_shuffled_results(topic_dict_list):
    for topics_dict in topic_dict_list:
        word_pile = []
        for key in topics_dict:
            word_pile.append(topics_dict[key])
        word_pile = np.array(word_pile)

# %%
#try_shuffled_LSA(test)

# %% [markdown]
# # Now checking for side effects in WebMD reviews

# %%
def find_sideEffects_inReviews_FAERsinformed(revFile, sefile1, sefile2, faers=True):

    # Parsing reviews
    reviews, fullrevs = parseRevnew(revFile, return_df=True)
    if faers:
        cond = sefile1[sefile1.find('faers_results/')+14:sefile1.rfind('/')]
        medication = revFile[revFile.rfind('/')+1:revFile.find('_'+cond)]
        meds = pd.read_csv('UniqueMedications/Medications_unique_{:s}.csv'.format(cond), sep='$')['All names']
        meds = [allnames for allnames in meds if medication.lower() in allnames.lower().split(', ')][0]

    # Parsing side effects
    if faers:
        listSEs = parseSE_FAERs(sefile1, meds)
    else:
        listSEs = parseSEorig(sefile2)
        
    #new attempt
    listSEs1 = parseSE_FAERs(sefile1, meds)
    listSEs2 = parseSEorig(sefile2)
    listSEs = listSEs1 + listSEs2
    
    BagOSE = ' '.join([' '.join(SE) for SE in listSEs])

    # Finding review words that exist in the list of side effects
    found = [[word for word in rev if BagOSE.lower().find(' '+word.lower()+' ')] for rev in reviews]
    found = []
    for ind, rev in enumerate(reviews):
        item = {}
        for SE in listSEs:
            # Match words in reviews to side effects and then add them to found, build dataframe with this info
            item[', '.join(SE)] = len([word for word in rev if word.lower() in SE])
        found.append(item)
    
    SE_match = pd.DataFrame(found)
    SE_match['Full Review'] = fullrevs.values
    
    # Return the master product
    return SE_match

# %%
df = find_sideEffects_inReviews_FAERsinformed('ProcessedReviews/Bipolar-Disorder/Lamictal_Bipolar-Disorder_parsed_reviews.csv', 
                                              'NERstuff/faers_results/Bipolar-Disorder/SideEffectsExtracted.csv',
                                              'SideEffects/Bipolar-Disorder_SideEffects.csv')

# df = find_sideEffects_inReviews_FAERsinformed('ProcessedReviews/Bipolar-Disorder/Lamictal_Bipolar-Disorder_parsed_reviews.csv', 
#                                               'moddedSideEffects/Bipolar-Disorder_SideEffects_denormed.csv')

# %%
newdf = df.drop(columns='Full Review')
review_inds = []

# Allowing for two item side effects UNLESS they contain two very generic words
colLens = np.array([len(col.split(', ')) + 2*((col.find('feel') != -1)|(col.find('pain')!= -1)|(col.find('abnormal')!=-1)|(col.find('change')!=-1)|(col.find('disorder')!=-1)|(col.find('problem')!=-1)|(col.find('decrease')!=-1)|(col.find('increase')!=-1)|(col.find('loss')!=-1)) for col in newdf.columns])

for ind in newdf.index:
    if (((colLens < 3) & newdf.loc[ind].gt(0)) | newdf.loc[ind].gt(1)).sum(): 
        review_inds.append(ind)

# %%
for ind in review_inds:
    print(df.loc[ind]['Full Review'], '\n\n', 
          newdf.loc[ind][np.logical_or(np.logical_and((colLens < 3), newdf.loc[ind].gt(0)), newdf.loc[ind].gt(1))],
          '\n'*5)
# Out:
# I sleep just fine, I started at 25 mg and slowly went up to 100 mg currently. I'm tired and sleep great.no rash, no unbearable side effects.
#
#  trouble, sleep    1
# Name: 0, dtype: int64
#
#
#
#
#
# I did not get much sleep while on this medicine. The insomnia side effect is horrendous. Even with adding Ambien to the mix, I still would watch the sun rise. Also, the depersonalization side effect is pretty bad. I just didn't care about anything, and my passion for art was completely gone.
#
# I won't ever take this medicine again.
#
#  trouble, sleep    1
# Name: 1, dtype: int64
#
#
#
#
#
# My response is to Susie! She began at a very high dose 100 mg. Lamictal has a black box warning. You need to carefully titrate up on it. Otherwise, you will get the famous Lamictal Rash. I cannot believe anyone would prescribe Lamictal like that carelessly to a patient!! I started out at 25 mg adding 25 each week till I got to my Theraputic Dose of 300 mg. Began when I was 45 and off and on ( I felt better, so I stopped, good grief!) I'm now 64 and glad to be back on the drug. It's great. Takes awful, is my only complaint.
#
#  like, kidney, pressure, high, failure    2
# Name: 3, dtype: int64
#
#
#
#
#
# I've been taking this medication for about a year and it's been very effective for me. It helps me feel more steady and stable, and avoid the constant highs and lows of bipolar. My doctor upped my dose when I began a severe bout of sleepwalking after coming off a strong sleep med. After increasing lamotrigine I stopped sleepwalking. My experience with the med has been nothing but good.
#
#  feel, constant, movement, self, surrounding                              2
# increase, sensitivity, skin, sunlight, redness, discoloration, severe    2
# trouble, sleep                                                           1
# Name: 4, dtype: int64
#
#
#
#
#
# I hate this medication! I'm 48 and was diagnosed as BP2 4 months ago. Started this med at 100mg, 2 weeks later, 150mg, 3 weeks later 200mg. I"ve had no sleep since starting this med. Because I've had such a horrific time sleeping, I've been so close to loosing my mind. Having hot flashes like crazy, had them slightly before due to being postmenopausal, but even then it was doable because I was not up all night tossing and turning. No sleep, weeping, and worsened depression. Actually thought I'd rather be dead. This sucks!!!!! I am weaning myself off, not sure I will trust any doctor after taking this shit. I was better off on Prozac, at least I didn't want to bite my spouse's head off, nor did I feel like I just wanted to die. This med has made me Bipolar! It's been the worst 4 months of my life, glad I'm still here to tell you not to take this. I quit my job, I nearly lost my marriage which was a gamble I was not prepared to take. Do not take this at high dosages if you can't handle it at the low dosage, you are taking a chance on making your  condition worse.
#
#  illogical, connective, think, administration, loose    2
# like, kidney, pressure, high, failure                  2
# trouble, sleep                                         1
# Name: 5, dtype: int64
#
#
#
#
#
# I just started this medication like 2 days ago. I just got diagnosed as bipolar and iâ??ve been suffering with depression for 10 years now. It started when I was 25 yrs old. I was told by my Dr to take this medication at night with my antidepressant which is Celexa. Iâ??ve been experiencing major headaches that lasts all day, nausea, vomiting and upset stomach. On top of that, I canâ??t sleep well. It had me up all night tossing and turning. Come Monday morning Iâ??m calling my Dr and hope she DC this and try me on something else.
#
#  throw, vomit      1
# headache          1
# trouble, sleep    1
# vomit             1
# Name: 7, dtype: int64
#
#
#
#
#
# I have taken this medication for over 7 years now and  have found it to be very effective in treating my bipolar II.  I have not had any side effects (which is odd since with most meds that I have tried over the years nausea and stomach issues are usually the side effect that i get the most frequently).  When my Doctor and I finally came up with the medicine combo that worked for me I had been in a pretty rough state for over 2 years
#
#  nausea                 1
# stomach, discomfort    1
# Name: 8, dtype: int64
#
#
#
#
#
# I started this med almost 2 weeks ago for Bipolar II.  Seemed to be working even at the starter dose. Then boom! Hives and severe itching. My Doctor told me to stop the drug if I had any skin reaction. So now I stopped it and I have crashed!  See the Doctor next week on to the next drug.
#
#  redness, skin                                                            1
# hive                                                                     1
# discoloration, skin                                                      1
# dryness, skin                                                            1
# withdrawal, drug                                                         1
# blemish, skin                                                            1
# crack, skin                                                              1
# lesion, skin                                                             1
# dry, skin                                                                1
# increase, sensitivity, skin, sunlight, redness, discoloration, severe    2
# itch, skin                                                               1
# oily, skin                                                               1
# scaly, skin                                                              1
# Name: 9, dtype: int64
#
#
#
#
#
# I weaned myself off a heavy dose of zoloft after about 4 years. Depression just seemed out of control and just different. Got the bipolar depression diagnosis and started a low dose (25 MG daily at night) of lamotrigine. It's only been 4 days, my moods are definitely better but I have had the worst stomach cramping and diarrhea since the morning after my first dose. Here it is, 4:00 in the morning and I have been up all night with terrible stomach pains and diarrhea every hour. Please tell me this goes away soon!!
#
#  action, control        1
# cramp                  1
# diarrhea               1
# heavy, bleed           1
# leg, cramp             1
# stomach, pain          2
# stomach, discomfort    1
# Name: 12, dtype: int64
#
#
#
#
#
# I approached my doctor requesting treatment for ADHD and left with a prescription for generic lamotrigine to manage my moods.  I'm not bipolar, though; if anything I'm depressed, but my doctor latched onto the fact that once, about four years ago, I had a single and isolated "manic-like" episode that has never happened again.
#
# I've only been taking this a few months and have had my dosage increased once (25mg to start, 50mg currently). I realize that generally people don't experience any real change until the dosage is significantly higher, but if anything my "mood disorder" is worse and I've experienced several side effects since starting treatment with this.
#
# I'm more irritable and my already limited patience and temper are easier to lose than ever, to the point of rage, restlessness, and wanting to hurt people.  My nose has been congested for months in a way that has nothing to do with the season or allergies.  I have a constant minor headache and dry eyes--for a while, my upper eyelids would periodically twitch, but that stopped when my dose increased.  My skin is more sensitive and I'm ore prone to irritation than I was.  I already had issues with menstruation and they've gotten worse.    As I type this, I have a tightness in my chest that's only happened since I started taking lamotrigine.  I've had issues with urination, from not going enough and having difficulty going to needing to go so immediately I'm lucky I make it to the bathroom.  I'm fatigued and have occasionally severe insomnia and nightly vivid, sometimes upsetting dreams.  I have the same issues with concentration that I've always had, but I've become prone to trailing of mid-thought and misspeaking or being outright incoherent.  I'm not well-coordinated to begin with, but I've gotten worse as my grip has gotten weaker and my balance is off (I even walk differently now to compensate.
#
# My doctor insists I stay on and up my dose again to see if things change.  I don't want to take the chance.
#
#  eyelid, inflammation    1
# stuffy, nose            1
# Name: 13, dtype: int64
#
#
#
#
#
# I was diagnosed with Bipolar II early this year after some years of being misdiagnosed with plain ol' depression.  One way I differ from the usual B2 person is that I've never really had suicidal thoughts - except on the Citalopram and Trazodone I'd been prescribed for depression!  I worked my way up on the Lamotrigine from 25mg daily to my current 200, with zero side effects, and a marked improvement in my mental state after about two months.  Unless your early experiences are really bad, as mine were with the SSRIs, be patient and let "Vitamin L" work its magic.  It's not perfect and my mood swings haven't completely disappeared, but I'm a lot easier to live with now, sleep better and am more optimistic.  I'll gladly take this for the rest of my life if that's what it takes.  It should be noted that I also quit drinking and smoking pot this year, and I'm sure there were many cross-benefits from that.
#
#  wide, mood, swing    2
# trouble, sleep       1
# Name: 16, dtype: int64
#
#
#
#
#
# I had convulsive seizures and became paranoid.
#
#  seizure    1
# Name: 17, dtype: int64
#
#
#
#
#
# was prescribed for bipolar 2 (in generic). was on 12.5mg (25mg split in half) for about 3-4 days, and started getting sore throat, swollen lymph node, fever, and muscular pain. stopped it for about a week, then tried another 12.5mg and immediately had a fever of about 102f and stiff neck. i was concerned about sjs, so quit the med right there and then.
#
#  hypotonia, muscular            1
# node, lymph, swell, enlarge    2
# chill, fever                   1
# fever                          1
# stiff, neck                    1
# Name: 18, dtype: int64
#
#
#
#
#
# I was diagnosed with Bipolar Disorder II and Dysthimic Disorder about a month ago and was prescribed Lamictal (Lamotrigine). I'm now taking 100 mg a day and have gradually seen an awesome change. My mood swings aren't as extreme and it's helped a lot with the depressive symptoms as well.
#
#  bipolar, affective, depressive, manic, disorder    3
# see, double                                        1
# wide, mood, swing                                  2
# Name: 19, dtype: int64
#
#
#
#
#
# This is one of the most difficult drugs to stop taking. I've been stepping down from 200mg/day over the last 3 years. 10 mg at a time. Takes a month of feeling like a complete idiot, with lots of drowsiness for me to start feeling better after reducing the dose... then you need another couple of months to restabilize. Glaxo lied in their first data sheet about effectiveness. Turns out that Lamictal/Lamotrigine is less effective than placebo. I wouldn't recommend this to anyone.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# drowsiness                                   1
# unusual, drowsiness                          1
# Name: 20, dtype: int64
#
#
#
#
#
# I have been on this drug for a year just in the last 3 mos my dose was raise to 250 a day as I began feeling very manic. It has only been a week but feel better. This drug has been my life saver.
#
#  withdrawal, drug    1
# Name: 21, dtype: int64
#
#
#
#
#
# I'm on week two of 25mg of this pill. In three days I will go up to 50 mg. the only change I've seen in my behavior is that it has gotten worse. I become irritated much easier than I did before I started taking this medication. I was diagnosed with bi polar and anxiety agitation. I hope there is a way to review again once my doses become higher. I'm giving this med a chance in hopes that it will help.
#
#  see, double    1
# Name: 22, dtype: int64
#
#
#
#
#
# BP2. Coming off lithium I found myself more energetic and dynamic. At first I was having some serious suicidal ideation, but that passed. Now the problem is that I'm beset by a feeling of bleakness, on occasion. It's not entirely like depression, being without emotion or fear.
#
#  lack, feel, emotion    2
# Name: 23, dtype: int64
#
#
#
#
#
# After quite a few years of a misdiagnosis and treatment for depression and/or ADD, I was accurately diagnosed with bipolar disorder and prescribed Lamotrigine.  I have been taking 300mg for almost 10 years now, and I am thrilled with the level of stability I have experienced over these years.  Overall I'm very happy with my experience with this medication.
#
#  bipolar, affective, depressive, manic, disorder    2
# Name: 24, dtype: int64
#
#
#
#
#
# Went off celexa for anxiety. Slowly worked up to 200 mg. felt like I was going to jump out of my skin with the first 200mg dose. It seems 9 hours after I take it I become very nauseous, and have diarrhea. Wake up out of a dead sleep, feel like I have the stomach flu. Cut down to 100mg, still feeling like that. First they gave me Lamasil (sp) to ease into full strength then the full dose was lamotrigine. No effects with Lamasil. Woke up this morning feeling sick, now I have a slight rash on my face and body.
#
#  redness, skin                                     1
# discoloration, skin                               1
# dryness, skin                                     1
# blemish, skin                                     1
# crack, skin                                       1
# bloat, feel, pressure, stomach                    2
# lesion, skin                                      1
# dry, skin                                         1
# itch, skin                                        1
# oily, skin                                        1
# rash                                              1
# rash, flat, lesion, small, raise, lesion, skin    2
# scaly, skin                                       1
# stomach, discomfort                               1
# Name: 26, dtype: int64
#
#
#
#
#
# I am lucky that I have not had any side effects from this medication. For me it took a number of months to build up the effective dosage of 200mg per day.  However, despite the improvement due to Lamotrigine my mood (due to Bipolar II) has still been unstable.  So now I have just started on Seroquel XR.  Good luck and good health to all of you with bipolar disorder and remember MENTAL HEALTH IS TRICKY
#
#  bipolar, affective, depressive, manic, disorder    2
# Name: 27, dtype: int64
#
#
#
#
#
# After 12 years of misdiagnosed bipolar depression and heavy side effects from fluoxetine and citalopram my new psychiatrist cured me in 6 weeks with lamotrigine. I wish this had happened years ago! First week I had tremors and the second-third my insomnia worsened, but symptoms subsided after 2-3 weeks. It really works!
#
#  heavy, bleed    1
# Name: 29, dtype: int64
#
#
#
#
#
# I have taken this drug since 2009; I was lucky that the first drug I tried for my mental illness has been so effective. I take 300 mg once a day.
#
# Though it is technically prescribed for manic depression (for insurance coverage/medical reasons) it is actually for Borderline Personality Disorder.
#
# It brings me, and my doctor, a lot of hope, because it is commonly believed that personality disorders cannot be helped with medication. My moods are more stable, and even though it hasn't had any 'magic effect', it's given me the foundation to work on my own problems without constantly feeling like my world is collapsing around me.
#
# Warning for women: the interactions with birth control are VERY REAL. I spent a year and a half trying various combinations under my doctor's supervision, and every hormonal birth control option literally made me the most crazy I've been in my life-- crying constantly, suicidal, flipping out. I chose, in fact, to seek sterilization at a young age (for many reasons, but my need to stay on Lamotrogine is one of the primary ones).
#
# As far as long term side effects, my hands shake noticeably at times, and it seems like my balance is a bit worse, though that might just be the effect of aging. It is also incredibly difficult and distressing to miss a dose: headaches, dizziness, and extreme mood swings.
#
# Despite all of this, I am incredibly grateful for this drug. I didn't believe that a psych drug could ever change my life like this. It takes awhile to begin its effects but I would give it a chance if you have mood swing issues-- just take it consistently, at the same time each day.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    3
# action, control                              1
# tremble, shake                               1
# Name: 30, dtype: int64
#
#
#
#
#
# I take Lamotrigine once daily at 200 MG Tabs. I have been taking the medication for about a year now along with ocarbazepine 600mg. (Oxcarbazepine: one tablet by mouth three times a day.) Only issue is I am up more than 15 hours a day. Ask your Dr. about my regime. It has been pretty effective.
#
#  dryness, mouth    1
# water, mouth      1
# Name: 31, dtype: int64
#
#
#
#
#
# Not sure if it causes my migraines to be more frequent ?
#
#  cause    1
# Name: 35, dtype: int64
#
#
#
#
#
# I have been using this drug from 2006 which I found very effective.
#
# I am very happy with this drug
#
#  withdrawal, drug    1
# Name: 38, dtype: int64
#
#
#
#
#
# Helps me control my anxiety a bit better.
#
#  action, control    1
# Name: 39, dtype: int64
#
#
#
#
#
# I have taken Lamotrigine for 12 years now. Most of all, it seems to level my moods.  I take 400 mg at bedtime, along with 100mg of Zoloft, and during the day I take 300mg of Welbutrin. I wouldn't say I'm on top of the world, but I am in a stable place. The main concern I have is a side effect no one has reported. If I skip a dose, I start to have fuzzy thinking and feel uncoordinated. If I forget to take it at night, I have a very hard time waking up and I feel awful. If I go to work after skipping a dose, I have to have someone bring it to me, so that I won't get disoriented and anxious. I don't like that aspect of this drug at all. I've been on it long enough to know that these side effects are produced by Lamotrigine, not another medication.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 40, dtype: int64
#
#
#
#
#
# Doesn't work for me!  Down taking at present to stop entirely.  Enough lifetime liver damage although suppose to be ok with liver interaction.  Just a piece of advice...IN MY LAY OPINION there is absolutely NO Drug that doesn't somehow effect the liver on different levels.  DO NOT let doctors tell you otherwise.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 41, dtype: int64
#
#
#
#
#
# This is the only drug which helps with the depression part of my being Bipolar.. I do take xanax with it for my anxiety..I do believe the brand name drug Lamictal works much better , but my insurance will not pay for it.
#
#  withdrawal, drug    1
# Name: 43, dtype: int64
#
#
#
#
#
# For 15 yrs I was put on to many antidepressants to list. Everyone in my life can tell a huge difference. Part of bipolar is thinking your all better and stopping your meds. Within 2 days I hit a low and can't think rationally. As soon as I am back on it I am level headed. Only bad part is my memory has gotten bad. Could be hormonal though. I had a total hysterectomy. Overall this drug probably saved my life and my relationships.
#
#  withdrawal, drug    1
# Name: 44, dtype: int64
#
#
#
#
#
# Slowly thinking clearer. and my mood swings are less frequent.and my depression seems to be getting better. But its only been 2 weeks, so still in testing mode. So far seems to be working .Having some weight gain, and not peeing much., don't know if its due to meds yet.
#
#  wide, mood, swing    2
# weight, gain         1
# weight, los          1
# Name: 45, dtype: int64
#
#
#
#
#
# i dont see a change still having mood swings and irritability
#
#  irritability         1
# wide, mood, swing    2
# Name: 47, dtype: int64
#
#
#
#
#
# As far as my bipolor goes its way better but, it causes a terrible , unbearable rash and nothing soothes the rash. I cant sleep or sit still long. Im miserable.
#
#  cause             1
# rash              1
# trouble, sleep    1
# Name: 49, dtype: int64
#
#
#
#
#
# the mouth & tongue sores.  But it really works for my depression.  What can I do?
#
#  dryness, mouth                         1
# irritation, soreness, tongue, mouth    2
# soreness, tongue                       1
# water, mouth                           1
# Name: 51, dtype: int64
#
#
#
#
#
# The only reason I gave this med a low ease of use score is the slow dosage build up.  It takes a long time to reach the theraputic dose.  I did so well on this med -- no side effects and felt so normal.  After about 6 great months, I started thinking that I was just so ok ... and that the bi-polar stuff was all in my mind and a missdiagnosis by the doctor.
#
# I quite taking it ... was great for a month ... and then WHAM ... major depression.  Right now I am trying to cope with a hypomanic state (just yesterday I did something potentially hurtful & feel just terrible about it today) while I wait to once again reach the theraputic dose.
#
# I learned my lesson!! I will never agin get off this wonder drug!!
#
# I hope that someone who is successfully taking this drug will read this and learn from my bad experience.  STAY ON YOUR MEDS!!
#
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 53, dtype: int64
#
#
#
#
#
# god i hate this drug. okay, so it takes a while to titrate up. i got put on it because i was very near overdosing on prozac. they thought that since i went manic/depressive on it that i had bpd2. which i guess makes sense. but the whole time i was titrating up i had to seriously fight in order to keep myself from killing myself. "oh, it'll work pretty soon, just wait until you get a higher dosage." funny story, i'm at 200mg and it does absolutely nothing. it's inhibited a lot of my creativity and taken out a big chunk of my mental capacity, but it really hasn't done anything. i still have suicidal ideation, and the only thing stopping me is not wanting to hurt my family. however, if depressed enough, that does not matter because my body automatically tries to end it's suffering, so it's really very important that i have something blocking all levels of depression. all it does is stop me from being manic, which, personally, i'd rather be manic all the time than depressed. now i have to stop cold turkey because my psych canceled my appointment, and i've been off one day and have started hearing voices and feeling presences at night and having panic attacks. i don't know, this might mean i'm schizoaffective but whatever. this drug was a pain to get on (constant nausea, pounding headaches, and at times severe crippling depression) and at this point my body has developed a very strong aversion to taking it. im going to a new psych next week to get evaluated. this drug sucks.
#
#  bipolar, affective, depressive, manic, disorder    2
# withdrawal, drug                                   1
# interaction, take, medical, certain, drug          2
# cold, sweat                                        1
# hear, los                                          1
# Name: 55, dtype: int64
#
#
#
#
#
# doctor wants me on 200mlg and I dont want to take that much. I wonder if the med has anything to do with my body stiffness and pain?
#
#  muscle, stiffness    1
# Name: 56, dtype: int64
#
#
#
#
#
# Taking it for bipolar II for over a year. Until the dose steadied out I felt unsteady, even worse than unmedicated. After getting to the therapeutic dose and staying there for a while, things got better. My wife notices an enormous difference. I still am occasionally hypomanic, but any depression I have is very short-lived and not as severe as before. This is not a good drug for children, from what I read.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 58, dtype: int64
#
#
#
#
#
# After trying several antidepressants and lithium, the doctor prescribed lamotrigine/lamictal and wellbutrin/bupropion which has helped alot. lithium didn't help at all and caused rapid weight gain once i reached 1000mg (theraptutic level)and thyroid problems and was still depressed even depite trying celexa, citopram, and wellbutrin combined with the lithium. discouraged, i went in and asked to be taken off my drugs and she said to try this before making such a hasty decision and it worked! lamictal took away my anger/aggression and depression slightly so she prescribed wellbutrin to help with the depression and it was a life changer! it takes a while to reach a theraputic level (over a month) but with each week, i felt better. what people have to remember is that each drug effects different neurotransmitters in your brain and each person is different. plus, people are more likely to review when they're disatisfied, rather than happy so that also screws witht he rating. I say try it and see if it helps! I take mine before i want to go to sleep and you do get drowsy but when i wake up that doesn't effect me as much. wellbutrin is also a stimulant so that may be another factor. start with a low dose (25mg) and increase weekly by 25 mg to lessen the chance of getting the rash which is rare. before this drug, i wanted to kill myself and was very angry and depressed despite being on lithium which most bipolar people find effective; just not me. each person is different. be willing to try different drugs or combinations and be patient because there is a theraptuic level you have to reach.
#
#  belief, delusion, outside, despite, object    2
# thyroid, enlargement                          1
# withdrawal, drug                              1
# interaction, take, medical, certain, drug     2
# Name: 59, dtype: int64
#
#
#
#
#
# My son is 14 he has been changed to this med he is refussing to take it makes him feel funny I am so sick of the doctor he does not listen just writes out diffrent meds he gets so angry he dont even wanna take it he is bipo & ADD & has night terriors sleep walks i'm so lost we have been on a waiting list for almost two years to get him in with a child specilist we go in two weeks I pray they can help before my son committs suicide or hurts someone else from his anger i have to have to hold him and tell him how much he means to me to get him to calm down very sad & not a good life for a young boy.Parents becareful of this drug for your child we are needing help with our kids not drugs that are gonna make things worse.I think or belive that his started at birth i started noticing it when he was about 3 yrs of age now he is a 9th grader still can't read maybe 2nd grade level .GOD WHAT HAPPEN TO MY BABY BOY????????
#
#
#  suicide, attempt    1
# withdrawal, drug    1
# shuffle, walk       1
# trouble, sleep      1
# Name: 62, dtype: int64
#
#
#
#
#
# i feel as though i am gaining a lot of weight and it isn't helping my anger, or freak outs or manic depression episodes. i am sideways all the time, i am always running around, i can't stay still, i am always panicking about something and still having extreme anxiety
#
#  gain, weight, body, increase    2
# weight, gain                    2
# weight, los                     1
# Name: 63, dtype: int64
#
#
#
#
#
# Have taking it for about a month. I think it is helping but all I want to do is sleep
#
#  trouble, sleep    1
# Name: 66, dtype: int64
#
#
#
#
#
# 20yrs ago I was diagnosed as having Chronic clinical Depression.  After many years on many different drugs causing weight gain an inability to work or take care of my children.  I was diagnosed with Bi polar abt 4 years ago.  initially i was on prozac and epilum which worked together really well except I gained a tollerance and was on max doses with return of symptoms.  My new coctail (for abt 12months) has been lamotrogine 100mg twice daily.  I do not have any side effects.  I have always had trouble sleeping so I am taking a 25mg tablet of seroquel and 20mg temaze.  If i take any more that 25mg of seroquel it makes me eat non stop.  I have not had trouble with weight gain on the lamotrogin though.  Recently due to an episode of depression I started 50mg Pristiqe, it has worked but NO libido:(
#
#  gain, weight, body, increase                 2
# withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# inability, erection                          1
# cause                                        1
# trouble, concentrate                         1
# trouble, sleep                               2
# trouble, swallow                             1
# weight, gain                                 2
# weight, los                                  1
# Name: 68, dtype: int64
#
#
#
#
#
# Why would anyone give or take this medication knowing what the FDA warining is?!?! I just found out my ex put my daughter on it who is nowhere near bi-polar and I am completely angry that this drug is even still being prescribed to kids especially, my daughter is 13, and i beleive she has some ADHD issues, this medication does not help with that and she has done nothing but sleep since being on this one!
#
#  withdrawal, drug    1
# trouble, sleep      1
# Name: 70, dtype: int64
#
#
#
#
#
#  i started this drug some time ago,about 2 months, it has been effective until lately , i seem to cry a lot in the last month or so, going to see the doctor in a few days from now
#
#  withdrawal, drug    1
# Name: 72, dtype: int64
#
#
#
#
#
# I am 24 now and have been battling Bipolar Depression since I was 15. I have tried and been on many different types of prescriptions for this disorder. I have been taking this one for about 2 years now and I must say it has helped me greatly more than any other. The only problems I have really had with this prescription are weight gain and if I miss I dose I feel like crap.
#
#  gain, weight, body, increase    2
# weight, gain                    2
# weight, los                     1
# Name: 73, dtype: int64
#
#
#
#
#
# been on it for 3 months so far its helped a bit with my mood swings.May need something for my anxiety and panic attacks but all in all so far its good considering that its first mood stabilizer. :)
#
#  panic, fear, attack, chest, episode    2
# Name: 74, dtype: int64
#
#
#
#
#
# This has completely robbed what happiness I have had left. I'm only taking 50mgs and it's been a couple months. Just had a follow-up with the doctor & he is content with me being a zombie. I have not been diagnosed as bipolar, am more ADHD. I've heard nothing but awful things about this drug & not impressed myself.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# hear, los                                    1
# Name: 75, dtype: int64
#
#
#
#
#
# This medicine saved my life!!! I searched for a medicine that would help my bipolar depression for 15 years! And when I was prescribed Lamictal it was my last hope. Finally I dont feel so horrible and sad and worried and scared all the time, I feel NORMAL for the first time in my life, I dont have any more hallucinations (I used to in the middle of the night) and I feel peace and contentment inside. I had a bit of the rash side effect, you trully have to be careful with the dosage dont increse it fast and dont miss doses. The rashes went away after I was stabalized at one dose of 75mg per day. I LOVE THIS MEDICINE, I still take it forever
#
#  feel, sad    2
# rash         1
# Name: 76, dtype: int64
#
#
#
#
#
# After about 5 days things went south, very south! My good moods were great but the bad ones were toxic. Started going in to full blown manic rages and honestly wanted to hurt people! Couldnt figure out if it was the med or just me, so called pdoc and she said STOP! Been off about a week and started seroquel in the mean time. Noticed a difference in just 2 days off limictal so must have been the med. Starting new med today, hope it goes well! My pdoc explained to me that my reaction to meds might be odd cause of extensive past drug history. Depending on the length of time, amounts, and substance used you really do "rewire" your brain. Good to know.
#
#  withdrawal, drug    1
# cause               1
# Name: 78, dtype: int64
#
#
#
#
#
# I have experienced mood swings since I was a teenager. It wasn't until last yr that I KNEW that I couldn't continue on being "moody" and I sought help. I was resistant to the idea of meds. Once I gave in I went to my GP & tried anti-depressants, they made me distant and angry. I gave them a moment to see if I'd adjust, I didn't and I left them alone. I moved to Lamictal/Lamotrigine as per my Pdoc. As I moved up in dosage I began to notice that I no longer had issues w/getting out of bed or feeling suicidal. I no longer felt the need or want to drink, I could sit in bars w/my buddies and be happy w/out having a round or two or five! I no longer looked for sex everywhere I could find it. No more spending cash on god-knows-what for NO REASON at all. Side effects: insomnia, headaches, sometimes feeling a little distant, strange/vivid dreams...but TRUST me I'm MILES from where I used to be and that's alright w/me!
#
#  wide, mood, swing    2
# Name: 79, dtype: int64
#
#
#
#
#
# So far the medication has worked well with the exception of a little nausea in the morning.  I was taking 200MG and reduced to 150mg which greatly decreased the nausea.  I have taken many anti-depressants and this has worked the best.
#
#  desire, sexual, reduce, decrease                  2
# activity, biochemical, motor, reduce, decrease    2
# nausea                                            1
# Name: 80, dtype: int64
#
#
#
#
#
# This medication seem to help initionally (about three years ago) but now I'm experiencing confusion, unsteady gait frequently with loss of balance, difficulty  with concentration, short term memory loss, weakness, extreme fatigue requiring rest/nap about every few hours. Plan to discontinue with help from doctor.
#
#  gait, disturbance    1
# loss, memory         2
# Name: 81, dtype: int64
#
#
#
#
#
# Makes me too tired to function alot. Within an hour after I take it I have to shut my eyes and put my head down. But I can't take it at night because whenever I do, I don't sleep, despite being very tired. It's odd.
#
# I initally got prescribed this as a mood stabalizer. I get hypo-manic, and was never willing to get on a mood stabalizer untill I realized the older I get, the worse my depressions get. So my prescriber told me that lamictal would keep my depressions from getting SOO low, and keep my mania from getting TOO high.
#
# I don't really know if it's working, because I still get pretty depressed for long periods of time. Many just not as bad as it use to be, but not really noticeable either. I find myself unable to take this medication, unless I have a few hours in my day free where I know I don't have to exert myself or keep my eyes open. Waste of frickin time.
#
#  itch, eye    1
# Name: 83, dtype: int64
#
#
#
#
#
# I just started so I am still on a low dose, I feel more normal but I sleep alot when i am at home, idk if this is a se of the medication or of the depression that was about the worst i've experienced since i started having problems. I am currently titrating up on doeage and it is combined with Xanax so we will see how this works.
#
#  trouble, sleep    1
# Name: 87, dtype: int64
#
#
#
#
#
#  I take 200mgs along with 300mgs of Wellbutrin XL, 200 mgs of Zoloft, 3mgs of Xanax and 3mgs of Klonopin. This has worked very well for me. Previous doctor had me on Seroquel XR, and it turned me into a walking ZOMBIE, could not function. Seroquel XR is a terrible medication. I don't recommend this to ANYONE.
#
#  shuffle, walk    1
# Name: 89, dtype: int64
#
#
#
#
#
# Doing a lot better since taking this medicine. The only set back was I gained a lot of weight from taking it. Over all it is has been successful
#
#  gain, weight, body, increase    2
# weight, gain                    2
# weight, los                     1
# Name: 91, dtype: int64
#
#
#
#
#
# I have been taking the generic form of lamotrigine for 5+ years. Unlike some others, it has worked well in controlling my symptoms. I feel balanced. I experienced multiple major depressive events starting in my 30's which I treated by indulging in alcohol. Eventually I tried every SSRI on the market, Wellbutrin, Trazadone and several others. These made me manic and caused severe insomina. After taking lamotrigine for a couple or years, I began having panic attacks. My doctor added Xanax. It was the perfect combination and the most effective treatment to date. One thing is important - don't use drugs or alcohol if you expect to get the full benefits of this product. I haven't had a drink for 3+ years and this was the key to achieving maximum effectiveness. Substance abuse is a problem with many of us with bipolar depression. If that is a factor, you have to deal with that as part of the treatment plan. Not always easy to do, but worth it. I was teetering between a good life and losing it all. I didn't lose my life. Identifying the right combination of drugs and a good psychiatrist is key to finding the right thing for you. I take 300 mg per day - 150 mg morning and night with 50 mg Xanax at the same time. No side effects.
#
#  bipolar, affective, depressive, manic, disorder    2
# withdrawal, drug                                   1
# interaction, take, medical, certain, drug          2
# action, control                                    1
# Name: 93, dtype: int64
#
#
#
#
#
# My doc started me on 200 mg a day, i have noticed after2-3 hours i have to take a nap, and when i get up have severe headache. i am now at 3 months and fell asleep holding grandbaby. sleepiness is worse as well as headache. but the bipolar symptoms have disapperared. thinking of asking for a lower dose.
#
#  sleepiness    1
# Name: 95, dtype: int64
#
#
#
#
#
# I have no side effects like I had with Paxil. It makes me feel "normal", eliminating lows and highs (I experienced more lows...) I truly recommend trying it if other antidepressants do not seem to be working,
#
#  like, kidney, pressure, high, failure    2
# Name: 96, dtype: int64
#
#
#
#
#
# I've been using this drug for 3 years. Yes on weight gain, confussion, head ache, ache's and pains. Psych dr took me off this past Thursday. So this is day 5 and I've been down for most of the day's. Anyone else come off this drug and have this same experience? I get up to do things and I'm back on the couch. No energy, sleeping alot. Dr. felt this might be causing the confusion and panic attacks. Any feed back would be appreciated.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# cause                                        1
# trouble, sleep                               1
# weight, gain                                 1
# weight, los                                  1
# Name: 99, dtype: int64
#
#
#
#
#
# headache
#
#  headache    1
# Name: 100, dtype: int64
#
#
#
#
#
# I am on the generic form of this medicine. I have had weight gain and painful swelling in legs, feet and ankles. I have also noticed I am so tire all of the time and have severe pain, legs arms, joints, hands all of the time. My body feels like it goes to sleep on one side. Has any one else experienced any of the following? My doctor says that its not the medicine, I don't believe him.
#
#  gain, weight, body, increase                   3
# lose, reduction, weight, reduce, body          2
# mania, hyperactivity, form, elevate, severe    2
# leg, cramp                                     1
# trouble, sleep                                 1
# weight, gain                                   2
# weight, los                                    1
# Name: 101, dtype: int64
#
#
#
#
#
# i tried this for about a mont started with low dose had to upgrade started getting what looked like zits on my but just about 5 then i had 10 just on 1 side and about 9 on the other side then found rashes around the upper parts of legs around my private area dr told me to lower dose but was still breaking out so had to stop taking it after 10 days some rashes are clearing up except the buttocks area
#
#  leg, cramp    1
# rash          1
# Name: 102, dtype: int64
#
#
#
#
#
# Less rapid mood swings (mellow to angry). Doesn't work when taking alcohol. Feeling more in control of feelings and emotions. Focus is less difficult. Not as much clutter and disorganization of thoughts. Seems to help with my feeling towards organization "that glass sitting in the sink" when I go to bed isn't keeping me awake at night. Can sit and relax for longer period of time.
#
#  period, work, capacity, energy, lessen    2
# action, control                           1
# wide, mood, swing                         2
# Name: 103, dtype: int64
#
#
#
#
#
# I have been taking this med for months and it has helped better then others (too many to list). I take a handful of prescriptions daily to maintain a "level head", I apprently ran out of this prescription and it took me 2 to 3 days to figure out that it was missing...by morning of day 3 I was ready to crawl back into bed as I had been for the prior 2 days. I called the pharmacy, they told me to be cautious about lapsing with any of these meds and jumping back into them without going back to the DR. I have also had major memory and confussion problems....it has raised problems with going back to school and getting licensing obtained. Have any others had memory problems?
#
#  problem, memory    2
# Name: 106, dtype: int64
#
#
#
#
#
# I've been taking it for about 6 months and I feel like I can think clearly, and do things with out freaking out. This is the only med that hasn't made me sleepy, or gain weight. I've always was told that I was a bipolar 2 and wasn't. I have mild mood disorder that needs just a little bit of this med to keep me going with out all the side affects.
#
#  bipolar, affective, depressive, manic, disorder    2
# weight, gain                                       1
# Name: 108, dtype: int64
#
#
#
#
#
# I just started taking this, almost 2 weeks now, after many years of being misdiagnosed.  I am still on my depression meds (pristiq & welbutrin) but I am feeling much better.  I am a little more restless and not sure I want to up the dosage next week.  I am not having the mood swings I was having.  Next will be stoping the depression meds and just staying on this.  If this is how I am going to feel, I am all for this medication. This is the first time I can remember that I an enjoying life.
#
#  wide, mood, swing    2
# Name: 109, dtype: int64
#
#
#
#
#
# My mood swings have subsided to a lesser degree, but my sleep pattern is out of whack.  I'm up all night and want to sleep in the afternoon.  I also take Trazodone for sleep. Is there a connection between the two?  Who knows?
#
#  wide, mood, swing    2
# trouble, sleep       1
# Name: 110, dtype: int64
#
#
#
#
#
# This drug has made my life so different. No more telling clerks what I think, not pleasantly, but loudly. No more huge mood swings. One thing though, Has anyone been falling down? This very sudden, I can't save myself. please let me know , because it is not mention on any site that it is possible for this to happen. I also take trazadone, effecksor,and wellbutin.
#
#  withdrawal, drug    1
# Name: 111, dtype: int64
#
#
#
#
#
# i took this med for about 1 year, i weaned myself off about 5 months ago. i'm not sure that it really helped my situation, and think the change in birth control pills i was taking helped it more. the only thing is you cant just stop taking it cold turkey, i tried that and pretty much had an out of body experience, very odd and bad. but i weaned down by 50% a week till i was at 50mg and then stopped and it was fine. i didnt notice any side effects though or anything negative about the medicine
#
#  action, control    1
# cold, sweat        1
# Name: 112, dtype: int64
#
#
#
#
#
# just started takin drug but if this doesn't work not sure if they can find a drug to work.
#
#  withdrawal, drug    1
# Name: 113, dtype: int64
#
#
#
#
#
# I have been using Lamotrigine for 9 mos. My mood swings are under control. However my memory has deteriorated, I also have uncontrollable jerking with my hands. When I started this drug, I had these problems, but they are significantly worse. Has anyone else had these problems?
#
#  jerk, muscle         1
# wide, mood, swing    2
# Name: 117, dtype: int64
#
#
#
#
#
# After trying many mood stabilizers and anti-depressants that never worked, this was like a miracle drug.  For the first time in my adult life, I was able to function normally and finally felt that I knew what regular people felt like.  It has made a huge improvement in my mood swings, and control of the thoughts that lead to the mood swing.  Having tried so many different meds, I never believed I'd find one that helped but this did.  It saved my life.
#
#  action, control    1
# Name: 118, dtype: int64
#
#
#
#
#
# This was very effective in balancing my moods. I felt very calm. I was easy to get along with and had so little anxiety that I had no fear even when in situations that normally made me go into panic attack mode. However, I was always tired and exhausted my entire life before taking this drug. So when on this drug I was so tired that I could only sit and stare and not get much done during my day. I was in a zombie like state. Also it made me exrtremely forgetful. I missed 4 appointments in 2 months and I NEVER forget appts. I was just NOT motivated to do anything. It might be great for you if you have no probs with energy level. But for me the side effects were not worth it. I was taken off of it and use the aplenzin ER 348 for ADHD and it helps with Biolar depression as well.
#
#  panic, fear, attack, chest, episode          3
# withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# fear                                         1
# Name: 119, dtype: int64
#
#
#
#
#
# Wow. I am amazed with this drug and the effect that it has had for me. I have been unsuccessfully treated for depression and anxiety for several years however not many depression meds have worked or worked for long.  I was on daily ativan w/ little relief for anxiety. When the dr suspected bipolar II I was skeptical. Once I hit week four of lamotrigine I was amazed that I can actually feel normal again.  Even happy.  What a bonus.
#
#  withdrawal, drug    1
# Name: 122, dtype: int64
#
#
#
#
#
# was diagnosed bipolar 6 months ago or so, started out on lithium and it gave me hives was then put on lamotrigine 200 mg a day.  was originally sleepy all day so i switched to taking it at night.  i feel great and would not switch this drug for the world
#
#  hive                                         1
# withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 125, dtype: int64
#
#
#
#
#
# No manic episodes. After taking Lamictal for 18 months I know it's helped and hasn't caused the weight gain I had when I took Geodon. Initially, Lamictal caused terrible insomnia when I took it at night. If I took it in the morning, I vomited. My doctor then precribed trazodone, to be taken at night with the Lamictal, which helps with sleep. I've even been reducing the trazodone and can still sleep, but still cannot take Lamictal on an empty stomach anytime.
#
#  gain, weight, body, increase             2
# lose, reduction, weight, reduce, body    2
# cause                                    1
# stomach, discomfort                      1
# weight, gain                             2
# weight, los                              1
# Name: 127, dtype: int64
#
#
#
#
#
# became very sick dizzy vomiting passout and crying none stop and very angery
#
#  throw, vomit    1
# vomit           1
# Name: 128, dtype: int64
#
#
#
#
#
# been on this drug for 7 weeks..no difference in how i feel..not to happy about the constant explosive diahrea.
#
#  withdrawal, drug    1
# Name: 130, dtype: int64
#
#
#
#
#
# ...
#
#  chill                                        1
# withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# chill, fever                                 1
# cause                                        1
# Name: 1096, dtype: int64
#
#
#
#
#
# I take this along with Lexapro and Ativan to control my mood and it has worked brilliantly. I've been taking it for about four years and for the first time since puberty I have been almost completely  stable. I had trouble with anger and frequently losing my temper, self-harm, and compulsive exercising due to Bipolar II, and that has almost completely stopped since I started taking Lamotrigine. I went from several episodes per week to 2 in the past year.
#
#  action, control         1
# trouble, concentrate    1
# trouble, sleep          1
# trouble, swallow        1
# Name: 1097, dtype: int64
#
#
#
#
#
# I find it odd that so many people have such bad reviews yet also take an other prescribed medication. You have to take into consideration the fact that this medication reacts differently when there are multiple medications in your system. My doctor suggested Lamictal to me first for bipolar 2 disorder. I refused to take it because I had heard about the rash / stephen johnson syndrome, it had always been a fear so I absolutely refused to try it. I tried Abilify first, It seemed to change my life for the best until I started becoming exhausted and could barely walk down the street without having to rest. Could barely drive without having to take a nap on the side of the road. Turned out to be a side effect and I was taken off. I tried lithium as it was "affordable" and typical, it did nothing good for me, I was having awful mixed states, sudden crying spells, overly sensitive, and could not sit still for a minute, nothing improved so he took me off of it. Even with just two trials I told the doctor "fine, i'll try lamictal" well, about a year later it's changed my life for the good. I hate relying on medication but in all honesty the way this has helped me is well worth some sort of reliance. This was mostly to treat my depression, I don't get depressed as much anymore. I do have a phase here and there but it is much less severe than it used to be, i'll feel down but not so suicidal and completely worthless anymore. I will say though that the past two weeks have been interesting, I cannot tell what state I am in, I have once again become overly sensitive and easily irritable, the physical pain i've been in lately has been so confusing and awful (numb hands, tingling, crying, headaches, feeling light headed) very strange signs. Could easily be from something else but it's almost as if the meds just quit working out of the blue. However although i'm dealing with this, the depression is still nothing compared to what it used to be.
#
#  sensitivity, light                                   1
# manifest, proportion, excitement, physical, state    2
# fear                                                 1
# hear, los                                            1
# shuffle, walk                                        1
# Name: 1098, dtype: int64
#
#
#
#
#
# I have been on Effexor, Buspirone, Zoloft, Trazadone, Wellbutrin, Prozac, Klonopin over the years and this was by far the worst reaction I've ever had with a med. I was started on 25mg to move up after 1 week to 50 and was on it 5 days. The first few days I had severely painful headaches with pressure, my face twitches, my eyes rolled and darted back and forth and my jaw was clenched constantly. I had an extremely painful and stiff neck. Day 3 the pain was in all my muscles and joints and I had tremors. Day 5 and things got so bad I nearly went to an ER. 9 pm at night I started feeling like I was having a panic attack (I do have panic disorder). It felt as if my chest was in a vice grip and I couldn't breathe, my heart was beating rapidly/starting and stopping, pounding, I could see it pulse through my stomach. I had cramping in my abdomen and my neck was so stiff I couldn't move it. I did not sleep but more than that I couldn't move for hours. I laid in the fetal position completely wide eyed and in a state of what I mistook to be panic. My panic attacks have never lasted more than an hour or two. This lasted for 16 hours. I had to work in the morning and went to work on 0 sleep and all of symptoms kept worsening. I also had class but decided to go home to try to sleep because I was in so much pain. I started to put two and two together when everything in my body lit on fire. It felt like I had a sunburn, especially on my chest and back and neck. I called my prescriber and they said to stop taking it and to take the hydroxyzine because "it sounds like the beginning of an allergic reaction" as well as adverse effects. That makes it sound like they're competent and concerned...they aren't. They pushed this drug on me even though I was hesitant. It's five days later and only now am I starting to feel slightly back to normal but my face is still clenching and ticking and I'm still in pain. It took a few days for my pulse to even out, too. I DO NOT RECOMMEND THIS EVER
#
#  joint, ache, painful, pain             2
# joint, disease                         1
# throb, heart                           1
# sensitivity, light                     1
# panic, fear, attack, chest, episode    3
# jerk, muscle                           1
# ache, joint, muscle                    2
# itch, eye                              1
# cramp                                  1
# joint, muscle, pain                    2
# leg, cramp                             1
# muscle, stiffness                      1
# stiff, neck                            2
# trouble, sleep                         1
# Name: 1101, dtype: int64
#
#
#
#
#
# I got off zyprexa 6 months ago due to weight gain. I gained 130lbs on it. Zyprexa was the only drug I tried out of many that worked. After that I destabilized and had rapid mood swings and stopped sleeping. I found a new psychiatrist and he put me on Lamictal and Geodon. Within a month my mood swings greatly improved. And within 2 months I felt like a normal healthy human being again and my mood swings were relieved. Now, I no longer feel depressed or manic. I just feel happy all the time. I don't have anxiety anymore. I don't have depression anymore. I don't worry or get upset about every little thing anymore. This drug combo is like a miracle to me. Very easy to use with no side effects at all.
#
#  gain, weight, body, increase    2
# withdrawal, drug                1
# wide, mood, swing               2
# weight, gain                    2
# weight, los                     1
# Name: 1102, dtype: int64
#
#
#
#
#
# I have ultra, ultra, ultra rapid cycling manic depression. I have cycled daily many times. I am on lamictal 200mg and no side effects but I still cycle. I was on 300mg but it gave e a jeadach for 2 months ( for which the NP told me my brain was craving caffein)  and a stiff neck. I told the psychiatrist this over the phone and immediatley told me to stop taking for 7 days then slowly start back to 200 mg.
#
#  headache       1
# stiff, neck    1
# Name: 1103, dtype: int64
#
#
#
#
#
# I thought this was the one for over a year. It worked well for both for depression and mania. I had minimal side-effects (a little bit of brain fog). However, it has become completely ineffective for mania (3 episodes this year followed by 1 mild and 1 horrible post-manic depressive bouts).
# This was the fifth medication I have been on in the past seven years (they become ineffective after a while... or I stop fooling myself and recognize the symptoms again). I have been on this for 2 years and am up to 350 mg a day with progressively less effectiveness. Will be seeing what to do in a day or two...
#
#  see, double    1
# Name: 1104, dtype: int64
#
#
#
#
#
# have had cyclothymia for most of my life 55 years old-I've been on lamictal 175mgs for 5 years- this drug is miraculous!!
# changed my life-zero side effects-sleep is a joy! will stay on this until they plant me...
#
#  withdrawal, drug    1
# Name: 1105, dtype: int64
#
#
#
#
#
# This drug probably saved my life. I thought I'd taken everything, but nothing worked and i was on the brink of suicide. Lamotrigine brought me back.
#
#  withdrawal, drug                             1
# interaction, take, medical, certain, drug    2
# Name: 1106, dtype: int64
#
#
#
#
#
# Caused Suicidal thoughts and overdose.
#
#  cause    1
# Name: 1107, dtype: int64
#
#
#
#
#
# This drug has been my constant for many years.
# I take it with Geodon which has side effects. I still have anxiety, depression, auditory hallucinations which the Lamictal does not address.I have not gained weight. Hope this helps. I do not sleep, either.
#
#  withdrawal, drug    1
# weight, gain        1
# Name: 1110, dtype: int64
#
#
#
#
#
# I had been on the brand name "Lamictal" for about 6 years w/o issues. It has worked wonderfully for my manic episodes. The last two years I was switched to the generic brand by my insurance. During this time I had began getting a serious rash and redness and rash on my neck area, this past year I have developed blotches on my shoulders and upper arms as well as the shoulder blade areas. It is slowly working its way down my arms and back. My doctor gave me an ointment prescription which is working, but has concerns of the effects being related to Lamictal. He is weening me off due to the potential seriousness of this side affect. I am disappointed with this as the drug has worked perfectly for my condition, however, I appreciate his legitimate concern. I almost wonder if the generic brand may be the difference in my skin condition, where it has changed since being on the generic brand, rather than the name brand Lamictal oral. Regardless, should my rash subside once off the med completely, I will need to have a replacement med which i dread the experimental stage of alternatives. Lamictal has been perfect for me. I hate the thought of experimenting with other drugs due to concerns of being drowsy, high or always groggy from any particular med. I had once been on Depakote, which was a total nightmare. I can't bear the play on my system during this trial/error process. If the rash continues, the dr. will be sending me to a specialist to have allergy testing done. Yey.....
#
#  redness, skin                                                            2
# discoloration, skin                                                      1
# dryness, skin                                                            1
# withdrawal, drug                                                         1
# blemish, skin                                                            1
# crack, skin                                                              1
# lesion, skin                                                             1
# dry, skin                                                                1
# increase, sensitivity, skin, sunlight, redness, discoloration, severe    2
# itch, skin                                                               1
# oily, skin                                                               1
# rash                                                                     1
# rash, flat, lesion, small, raise, lesion, skin                           2
# scaly, skin                                                              1
# stiff, neck                                                              1
# Name: 1111, dtype: int64
#
#
#
#
#
# i am 38 and was diagnosed with manic depression at 14.i have taken 90% of all bipolar meds and bipolar med cocktails. lamictal is the closest chance i have to being as normal as i can be. good luck on the bipolar roller coaster.
#
#  bipolar, affective, depressive, manic, disorder    2
# Name: 1116, dtype: int64
#
#
#
#
#
# I have ultra rapid cycling bipolar I as well as generalized anxiety disorder and this medication, combined with buspar, abilify and celexa has helped me regain control of my life.before I began this medication I would have several manic or depressive episodes EVERY DAY. That is no longer the case. In fact, it has been several months since I have had either a manic or depressive episode. The only thing negative thing is that I no longer get those I'm-so-happy-happy-happy-that-I-could-fly feelings.Those were fun. Anyway, if I had to give up any of my meds, Lamictal would NOT be one of them.
#
#  bipolar, affective, depressive, manic, disorder    4
# faint, episode, principle, disorder                2
# action, control                                    1
# Name: 1120, dtype: int64
#
#
#
#
#
# Started four weeks ago on Lamictal.  50 mg to start and then titrated up to 100 mg two weeks later.  Only side effects I have had are congestion and severe migraines.  The migraines are getting better, less frequent...but the congestion remains.  Overall I am fairly satisfied with this drug.  I am going in for a follow-up in two weeks and will probably be titrated up another 50 mg.
#
#  congestion    1
# Name: 1121, dtype: int64
#
#
#
#
#
# The Lamictal worked. It was like the sun came out and the clouds parted. This was what it was like to feel in control of my life. Much less socializing without abandon, drinking, partying and spending money I didn't have. I was able to OBSERVE my impulses so I could decide whether or not to let them take over me.
# I had NEVER known what being "normal" was like. I felt like I could handle the anxiety and stress surrounding me with grace, maturity. My mood didn't dictate my actions as much.
# Then, my state's insurance company dropped me because I was taking classes at community college. I couldn't afford anything, not my psychiatry appts or my therapy. Apparently, if I can pay for school, I can pay for Blue Cross/Blue shield lower income insurance.
# Despair overtook me and I fell into a manic spiral of rapid cycling destructive behavior and avoidance,hiding in bed, isolating, crying all the time for no reason behavior. One day I was on top of the world, and everyone wanted to be around me. I loved life. The next, I hated myself and wanted to die. When I came out of that, I was an arrogant Bitch who thought she deserved better. Then I would suddenly feel inspired to get things done and have a normal day. I could feel my adderall working on those days. I could focus, but everything was short lived.
# I finished my classes and the state insurance picked me up again. I got back on Lamictal but had to take the Generic. I didn't care. I was SO HAPPY to get back on my mood stabilizer! About a month went by, then 2 weeks, and I met with my PA. I felt very laid back about chaos in my life. I didn't notice anything different. My attitude and quality of life had not improved on the Generic. but it hadn't really gotten worse. I felt like I always had. She switched me back to brand name and things started to improve again. Now taking tablets instead of ODT because of Medicaid. I notice quite a difference in side effects. Has anyone else switched? Effectiveness/infectiveness?
#
#  action, control    1
# Name: 1123, dtype: int64

# %%
len(review_inds), newdf.shape
# Out:
# (729, (1124, 344))

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer
import time
import pandas as pd
import numpy as np
import glob

# %%
# Starting with a single review document with a decent number of reviews
reviewFile = 'Reviews/bupropion-HCl_reviews.csv'
reviewDF = pd.read_csv(reviewFile, sep='$', 
                       index_col=1, usecols=(1,2,3,4,5,6,7),
                       converters={'date': lambda x: pd.to_datetime(x)})

# %%
reviewDF
# Out:
#                              conditionInfo  \
# date
# 2020-01-07 09:20:01  Condition: Depression
# 2019-04-18 09:00:45  Condition: Depression
# 2019-01-04 11:44:46  Condition: Depression
# 2019-01-03 10:05:42  Condition: Depression
# 2018-01-23 15:40:03  Condition: Depression
# ...                                    ...
# 2007-10-22 17:23:23  Condition: Depression
# 2007-10-14 12:56:40  Condition: Depression
# 2007-09-29 19:00:31  Condition: Depression
# 2007-09-27 16:07:15  Condition: Depression
# 2007-09-22 10:25:10  Condition: Depression
#
#                                                               reviewer  \
# date
# 2020-01-07 09:20:01                   Reviewer: 25-34 Male  (Patient)
# 2019-04-18 09:00:45  Reviewer: cant sleep, 35-44 Male  on Treatment...
# 2019-01-04 11:44:46  Reviewer: teechur, 45-54 Female  on Treatment ...
# 2019-01-03 10:05:42  Reviewer: guigeek, 45-54 Female  on Treatment ...
# 2018-01-23 15:40:03  Reviewer: 45-54 Female  on Treatment for 6 mon...
# ...                                                                ...
# 2007-10-22 17:23:23  Reviewer: k2skier, 25-34 Female  on Treatment ...
# 2007-10-14 12:56:40  Reviewer: ruthie, 45-54 Female  on Treatment f...
# 2007-09-29 19:00:31  Reviewer: robby 36, 65-74 Male  on Treatment f...
# 2007-09-27 16:07:15  Reviewer: FargoUT, 25-34 Male  on Treatment fo...
# 2007-09-22 10:25:10      Reviewer:  on Treatment for less than 1 month
#
#                      Effectiveness  Satisfaction  Ease of Use  \
# date
# 2020-01-07 09:20:01              4             5            5
# 2019-04-18 09:00:45              3             3            4
# 2019-01-04 11:44:46              4             3            5
# 2019-01-03 10:05:42              5             5            5
# 2018-01-23 15:40:03              3             1            4
# ...                            ...           ...          ...
# 2007-10-22 17:23:23              4             5            5
# 2007-10-14 12:56:40              1             1            4
# 2007-09-29 19:00:31              4             4            4
# 2007-09-27 16:07:15              4             4            5
# 2007-09-22 10:25:10              5             5            5
#
#                                                                Comment
# date
# 2020-01-07 09:20:01  No Script or health Insurance needed to place ...
# 2019-04-18 09:00:45  i just started this for a week now, all of a s...
# 2019-01-04 11:44:46  I started on Bupropion to deal with my depress...
# 2019-01-03 10:05:42  I have been taking Bupropion HCI XL 300 mg for...
# 2018-01-23 15:40:03  I have taken this for aprox 7 months.  I have ...
# ...                                                                ...
# 2007-10-22 17:23:23  Have tried many different antidepressant/mood ...
# 2007-10-14 12:56:40                                                NaN
# 2007-09-29 19:00:31  this drug caussed calmness, no anger, but a lo...
# 2007-09-27 16:07:15  After the loss of a loved one, I fell into a s...
# 2007-09-22 10:25:10  I have chronic depression and so far this medi...
#
# [201 rows x 6 columns]

# %%
def parse_reviewer(reviewer):
    # Find name as unique identifier if present
    if reviewer.find(',') != -1:
        name = reviewer[reviewer.find(':')+2:reviewer.find(',')]
    else:
        name = np.NaN
    
    # Find age range as datapoint if present
    if reviewer.find('-') != -1:
        if reviewer.find(',') != -1:
            age = reviewer[reviewer.find(',')+2:reviewer.find(' ', reviewer.find('-'))]
        else:
            age = reviewer[reviewer.find(':')+2:reviewer.find(' ', reviewer.find('-'))]
    else:
        age = np.NaN
        
    # Find gender if present
    if reviewer.find('Male') != -1:
        gender = 'Male'
    elif reviewer.find('Female') != -1:
        gender = 'Female'
    else:
        gender = np.NaN
        
    # Find treatment time
    if reviewer.find('on Treatment') != -1:
        if reviewer.rstrip()[-1] == ')':
            treatment_time = reviewer[reviewer.find('on Treatment for ')+16:reviewer.rfind('(')].strip()
        else:
            treatment_time = reviewer[reviewer.find('on Treatment for ')+16:].rstrip().strip()
    else:
        treatment_time = np.NaN
    
    # Put info in a dictionary that can be made into a dictionary
    reviewer_info = {}
    reviewer_info['Name'] = name
    reviewer_info['Age'] = age
    reviewer_info['Gender'] = gender
    reviewer_info['Length of treatment'] = treatment_time
    
    return reviewer_info

# %%
# Parse the reviewer info
reviewers = []
for reviewer in reviewDF['reviewer']:
    reviewers.append(parse_reviewer(reviewer))
reviewersDF = pd.DataFrame(reviewers, index=reviewDF.index)

# %%
# Drop the reviewer column from the original dataframe
reviewDF = reviewDF.drop(columns=['reviewer'])

# %%
# Add the parsed reviewer info to the original dataframe
reviewDF = pd.concat([reviewDF, reviewersDF], axis=1)

# %%
# Removing the label "Condition" from conditionInfo
conditions = []
for cond in reviewDF['conditionInfo']:
    conditions.append(cond.replace('Condition:','').strip())

reviewDF['conditionInfo'] = conditions

# %%
reviewDF
# Out:
#                     conditionInfo  Effectiveness  Satisfaction  Ease of Use  \
# date
# 2020-01-07 09:20:01    Depression              4             5            5
# 2019-04-18 09:00:45    Depression              3             3            4
# 2019-01-04 11:44:46    Depression              4             3            5
# 2019-01-03 10:05:42    Depression              5             5            5
# 2018-01-23 15:40:03    Depression              3             1            4
# ...                           ...            ...           ...          ...
# 2007-10-22 17:23:23    Depression              4             5            5
# 2007-10-14 12:56:40    Depression              1             1            4
# 2007-09-29 19:00:31    Depression              4             4            4
# 2007-09-27 16:07:15    Depression              4             4            5
# 2007-09-22 10:25:10    Depression              5             5            5
#
#                                                                Comment  \
# date
# 2020-01-07 09:20:01  No Script or health Insurance needed to place ...
# 2019-04-18 09:00:45  i just started this for a week now, all of a s...
# 2019-01-04 11:44:46  I started on Bupropion to deal with my depress...
# 2019-01-03 10:05:42  I have been taking Bupropion HCI XL 300 mg for...
# 2018-01-23 15:40:03  I have taken this for aprox 7 months.  I have ...
# ...                                                                ...
# 2007-10-22 17:23:23  Have tried many different antidepressant/mood ...
# 2007-10-14 12:56:40                                                NaN
# 2007-09-29 19:00:31  this drug caussed calmness, no anger, but a lo...
# 2007-09-27 16:07:15  After the loss of a loved one, I fell into a s...
# 2007-09-22 10:25:10  I have chronic depression and so far this medi...
#
#                            Name    Age  Gender           Length of treatment
# date
# 2020-01-07 09:20:01         NaN  25-34    Male                           NaN
# 2019-04-18 09:00:45  cant sleep  35-44    Male             less than 1 month
# 2019-01-04 11:44:46     teechur  45-54  Female        1 to less than 2 years
# 2019-01-03 10:05:42     guigeek  45-54  Female              10 years or more
# 2018-01-23 15:40:03         NaN  45-54  Female  6 months to less than 1 year
# ...                         ...    ...     ...                           ...
# 2007-10-22 17:23:23     k2skier  25-34  Female  6 months to less than 1 year
# 2007-10-14 12:56:40      ruthie  45-54  Female  6 months to less than 1 year
# 2007-09-29 19:00:31    robby 36  65-74    Male        2 to less than 5 years
# 2007-09-27 16:07:15     FargoUT  25-34    Male        2 to less than 5 years
# 2007-09-22 10:25:10         NaN    NaN     NaN             less than 1 month
#
# [201 rows x 9 columns]

# %%
for comment in reviewDF['conditionInfo']:
    print(comment, '\n')
# Out:
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression
#
# Depression

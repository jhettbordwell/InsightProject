# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer
import time
import pandas as pd
import numpy as np
import glob

# %%
# Grabbing original medications/SE dataframe
def makeListofStr(s: str) -> list:
    List = s[1:-1].split(',')
    List = [string.replace("'",'').replace(' ','') for string in List]
    return List

medsDF = pd.read_csv('Medications_SideEffects_brandAndlinks.csv', index_col=0,
                    converters={'Parent links': lambda x: makeListofStr(x), 'Exact medications': lambda x: makeListofStr(x)})

# %%
medsDF.head()
# Out:
#   Condition                Medication              Alternate names  \
# 0      ADHD          Methylphenidate   Methylin, Ritalin, Concerta
# 1      ADHD       Dexmethylphenidate        Focalin XR, SR Focalin
# 2      ADHD              Amphetamine         Adderall, Adderall XR
# 3      ADHD               Guanfacine                       Intuniv
# 4      ADHD  Clonidine Hydrochloride                        Kapvay
#
#                                          More common  \
# 0  Headache; loss of appetite; nervousness; stoma...
# 1  Acid or sour stomach; belching; heartburn; ind...
# 2  Dry mouth; loss of appetite; sore throat; stom...
# 3  Constipation; dizziness; dryness of the mouth;...
# 4                                     Constipation;
#
#                                          Less common  \
# 0  Anger; decreased appetite; dizziness; drowsine...
# 1                                        Twitching;
# 2  Belching; dizziness; heartburn; indigestion; s...
# 3  Belching; decreased appetite; decreased sexual...
# 4  Darkening of the skin; decreased sexual abilit...
#
#                                         Parent links  \
# 0  [https://www.webmd.com/drugs/2/drug-19735/meth...
# 1  [https://www.webmd.com/drugs/2/drug-22251-2094...
# 2  [https://www.webmd.com/drugs/2/drug-3670-6080/...
# 3  [https://www.webmd.com/drugs/2/drug-5481-8024/...
# 4  [https://www.webmd.com/drugs/2/drug-11754-24/c...
#
#                                    Exact medications
# 0  [methylphenidatepowder, methylphenidateHCL, me...
# 1   [dexmethylphenidateHCL, dexmethylphenidateHCLER]
# 2  [dextroamphetamine-amphetamine, amphetaminesul...
# 3  [guanfacineHCL, guanfacineHCLER, guanfacine(bu...
# 4  [clonidineHCl, clonidineHClSolution, clonidine...

# %%
def formatExactMed(s: str)->str:
    s = s.strip() # remove preceding and trailing white space
    s=s.replace(',','-') # Get rid of commas
    s=s.replace(' ', '-') # Get rid of white space
    s=s.replace('/', 'per') # remove things that make it look like a path
    return s

allfiles = []
for ind, medication in zip(medsDF.index, medsDF['Medication']):
    files = [glob.glob(formatExactMed(exactMed)+'*csv') for exactMed in medsDF.loc[ind]['Exact medications']]
    allfiles.append((medication, files))

# %%
allfiles
# Out:
# [('Methylphenidate ',
#   [[],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    []]),
#  ('Dexmethylphenidate ', [[], []]),
#  ('Amphetamine ', [[], [], [], [], [], [], [], [], [], [], []]),
#  ('Guanfacine ', [[], [], []]),
#  ('Clonidine Hydrochloride ',
#   [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Bupropion ', [[], [], [], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Venlafazine ', [[], []]),
#  ('Lithium', [[], [], [], [], [], []]),
#  ('Valproic acid ', [[], [], [], [], [], [], [], [], [], [], []]),
#  ('carbamazepine', [[], [], [], [], [], []]),
#  ('Lamotrigine', [[], [], [], [], []]),
#  ('quetiapine', [[], []]),
#  ('fluoxetine', [[], [], [], [], [], []]),
#  ('Sertraline', [[], []]),
#  ('Paroxetine', [[], [], [], [], []]),
#  ('Duloxetine', [[], [], [], []]),
#  ('Bupropion', [[], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Mirtazapine', [[], [], []]),
#  ('Aripiprazole ', [[], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Phenelzine', [[], []]),
#  ('Selegiline patch ',
#   [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Haloperidol', [[], [], [], [], [], [], [], []]),
#  ('Loxapine', [[], [], [], [], []]),
#  ('Aripiprazole', [[], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Asenapine', [[], [], []]),
#  ('Olanzapine', [[], [], [], [], []]),
#  ('Paliperidone ', [[], [], []]),
#  ('Risperidone ', [[], [], [], [], []]),
#  ('Ziprasidone', [[], [], []]),
#  ('Focalin', [[], []]),
#  ('Adderall', [[], [], [], [], [], [], [], [], []]),
#  ('Tenex', [[], [], []]),
#  ('Catapres', [[], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Aplenzin', [[], [], [], [], [], [], [], [], [], [], [], []]),
#  ('WellbutrinXL', [[], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Depakene', [[], [], [], [], [], [], [], [], [], [], []]),
#  ('Tegretol', [[], [], [], [], [], []]),
#  ('Lamictal', [[], [], [], [], []]),
#  ('Seroquel', [[], []]),
#  ('Prozac', [[], [], [], [], [], []]),
#  ('Sarafem', [[], [], [], [], [], []]),
#  ('Prozac', [[], [], [], [], [], []]),
#  ('Sarafem', [[], [], [], [], [], []]),
#  ('Zoloft', [[], []]),
#  ('Paxil', [[], [], [], [], []]),
#  ('Cymbalta', [[], [], [], []]),
#  ('RemeronSoltab', [[], [], []]),
#  ('Abilify', [[], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Seroquel', [[], []]),
#  ('Nardil', [[], []]),
#  ('Emsam',
#   [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Abilify', [[], [], [], [], [], [], [], [], [], [], [], [], []]),
#  ('Saphris', [[], [], []]),
#  ('Zyprexa', [[], [], [], [], []]),
#  ('Invega', [[], [], []]),
#  ('Risperdal', [[], [], [], [], []]),
#  ('Geodon', [[], [], []])]

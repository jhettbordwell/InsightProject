# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer
import time
import pandas as pd
import numpy as np
import glob
import csv

# %% [markdown]
# # Must process medsDF file to include info on brand name meds, in NLP, track number of tries by medication mentions

# %% [markdown]
# # Process the names into numbers...hashing of some kind?

# %%
# Grabbing original medications/SE dataframe
def makeListofStr(s: str) -> list:
    List = s[1:-1].split("'")
    List = [string for string in List if string and string != ', ']
    return List

medsDF = pd.read_csv('Medications_SideEffects_brandAndlinks.csv', index_col=0,
                    converters={'Parent links': lambda x: makeListofStr(x), 'Exact medications': lambda x: makeListofStr(x)})

# %%
def formatExactMed(s: str)->str:
    s = s.strip() # remove preceding and trailing white space
    s=s.replace(',','-') # Get rid of commas
    s=s.replace(' ', '-') # Get rid of white space
    s=s.replace('/', 'per') # remove things that make it look like a path
    return s

allfiles = []
for ind, medication in zip(medsDF.index, medsDF['Medication']):
    files = list(set([glob.glob('Reviews/'+formatExactMed(exactMed)+'_reviews.csv')[0] for exactMed in medsDF.loc[ind]['Exact medications'] if glob.glob('Reviews/'+formatExactMed(exactMed)+'_reviews.csv')]))
    allfiles.append((medication, files))
    

    
allfiles = dict(allfiles) 
for medication in allfiles:
    for i, file in enumerate(allfiles[medication]):
        if i == 0:
            #stackDF = pd.read_csv(file, sep='$', index_col=0, skip_blank_lines=False)
            print(len(pd.read_csv(file, sep='$', index_col=0, skip_blank_lines=False)))
        else:
            print(len(pd.read_csv(file, sep='$', index_col=0, skip_blank_lines=False)))
    #stackDF.to_csv('ProcessedReviews/{:s}_allconditions_reviews.csv'.format(medication.strip().replace(' ','-')), sep='$')
# Out:
# 24
# 7
# 309
# 179
# 179
# 8
# 33
# 33
# 23
# 38
# 179
# 179
# 33
# 179
# 179
# 179
# 58
# 1
# 1
# 1
# 13
# 161
# 20
# 20
# 13
# 13
# 2
# 88
# 45
# 45
# 88
# 60
# 60
# 45
# 640
# 1706
# 3
# 2
# 2
# 3
# 1
# 67
# 67
# 440
# 10
# 1
# 440
# 10
# 2
# 33
# 1
# 6
# 21
# 12
# 453
# 48
# 4
# 16
# 6
# 22
# 103
# 1
# 24
# 293
# 379
# 379
# 1
# 5
# 1673
# 16
# 379
# 780
# 625
# 3485
# 437
# 437
# 11
# 11
# 62
# 4
# 62
# 150
# 3
# 150
# 361
# 1
# 361
# 361
# 361
# 148
# 148
# 6
# 72
# 72
# 1
# 4
# 379
# 379
# 6
# 5
# 379
# 379
# 6
# 5
# 5
# 495
# 298
# 298
# 9
# 298
# 1586
# 180
# 460
# 460
# 135
# 135
# 1
# 1
# 24
# 379
# 379
# 1
# 5
# 16
# 379
# 3
# 355
# 355
# 2
# 53
# 53
# 2
# 53
# 2
# 148
# 148
# 6
# 3
# 3
# 3
# 1
# 4
# 3
# 4
# 2
# 2
# 12
# 8
# 2
# 20
# 11
# 2
# 53
# 53
# 2
# 53
# 2
# 7
# 41
# 1
# 7
# 6
# 72
# 72
# 1
# 4
# 5
# 16
# 197
# 197
# 5
# 120
# 1
# 8
# 607
# 1044
# 25
# 8
# 1
# 607
# 7
# 1
# 5
# 986
# 1103
# 986
# 1103
# 10
# 715
# 7
# 118
# 715
# 715
# 715
# 18
# 1
# 330
# 4
# 262
# 1
# 4
# 1
# 7
# 182
# 231
# 640
# 1706
# 23
# 2
# 2
# 16
# 8
# 12
# 57
# 120
# 23
# 22
# 1673
# 98
# 10
# 12
# 12
# 288
# 93
# 15
# 6
# 1273
# 35
# 47
# 23
# 2
# 61
# 1273
# 4
# 315
# 2444
# 7
# 470
# 20
# 2
# 43
# 2662
# 2223
# 4130
# 625
# 3485
# 4650
# 463
# 11
# 24
# 5
# 88
# 74
# 76
# 20
# 41
# 254
# 1
# 60
# 333
# 5
# 74
# 168
# 457
# 18
# 44
# 645
# 18
# 730
# 132

# %%
num_reviews = []; total2 = 0
for review in glob.glob('ProcessedReviews/*reviews.csv'):
    df = pd.read_csv(review, sep='$', skip_blank_lines=False)
    num_reviews.append((review, len(df.index)))
    total2 += len(df.index)

# %%
total2
# Out:
# 30008

# %%
df = pd.read_csv('Reviews/lithium-carbonate-oral_reviews.csv', sep='$', index_col=1, usecols=np.arange(1,8))

# %%
len(df)

# %%
pd.read_csv?
